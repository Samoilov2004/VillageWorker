# %%
import sqlite3
import pandas as pd

db_path = "../../databases/job_ads.db"  # путь к файлу

con = sqlite3.connect(db_path)

tables = pd.read_sql("SELECT * FROM sqlite_master WHERE type='table';", con)
print(tables)

# прочитать таблицу (замени table_name)
df = pd.read_sql("SELECT salary FROM jobs LIMIT 5;", con)
con.close()
# Out:
#     type  name tbl_name  rootpage  \
# 0  table  jobs     jobs         2
#
#                                                  sql
# 0  CREATE TABLE "jobs" (\n"id,title,salary,experi...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Desktop/myv-env/lib/python3.13/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: salary
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 12
#       9 print(tables)
#      11 # прочитать таблицу (замени table_name)
# ---> 12 df = pd.read_sql("SELECT salary FROM jobs LIMIT 5;", con)
#      13 con.close()
#
# ...

# %%
df = pd.read_csv("../../databases/job_ads.csv")

# %%
df.dtypes
# Out:
# id               int64
# title           object
# salary          object
# experience      object
# description     object
# key_skills      object
# company         object
# type            object
# address_info    object
# meta            object
# label           object
# dtype: object
